# %% [markdown]
# ## 1. What are escape characters, and how do you use them?

# %%
To insert characters that are illegal in a string, use an escape character. 
An escape character is a backslash \ followed by the character you want to insert.

# %% [markdown]
# ## 2. What do the escape characters n and t stand for?

# %%
An escape sequence is a sequence of characters that, when used inside a character or string, 
does not represent itself but is converted into another character or series of characters that may be difficult 
or impossible to express directly, like newline (\n), tab (\t), and so on.

# %% [markdown]
# ## 3. What is the way to include backslash characters in a string?

# %%
If you want to include a backslash character itself, you need two backslashes or use 
the @ verbatim string: var s = "\\Tasks"; // or var s = @"\Tasks"; Read the MSDN documentation/C# Specification 
which discusses the characters that are escaped using the backslash character and the use of the verbatim string litera

# %% [markdown]
# ## 4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the word Howl's not escaped a problem?

# %%
The single quote in Howl's is fine because you've used double quotes to mark the beginning and end of the string.

# %% [markdown]
# ## 5. How do you write a string of newlines if you don't want to use the n character?

# %%
Multiline strings allow you to use newlines in strings without the \n escape character.

# %% [markdown]
# ## 6. What are the values of the given expressions?
# ## 'Hello,world!'[1]
# ## 'Hello,world!'[0:5]
# ## 'Hello,world!'[:5]
# ## 'Hello,world!'[3:]

# %%
'Hello,world!'[1]
# Out:
# 'e'

# %%
'Hello,world!'[0:5]
# Out:
# 'Hello'

# %%
'Hello,world!'[:5]
# Out:
# 'Hello'

# %%
'Hello,world!'[3:]
# Out:
# 'lo,world!'

# %% [markdown]
# ## 7. What are the values of the following expressions?
# ## 'Hello'.upper()
# ## 'Hello'.upper().isupper()
# ## 'Hello'.upper().lower()

# %%
'Hello'.upper()
# Out:
# 'HELLO'

# %%
'Hello'.upper().isupper()
# Out:
# True

# %%
'Hello'.upper().lower()
# Out:
# 'hello'

# %% [markdown]
# ## 8. What are the values of the following expressions?
# ## 'Remember, remember, the fifth of July.'.split()
# ## '-'.join('There can only one.'.split())

# %%
['Remember,', 'remember,', 'the,', 'fifth,', 'of,', 'July.']
'-'.join('There can only one.'.split())
# Out:
# 'There-can-only-one.'

# %% [markdown]
# ## 9. What are the methods for right-justifying, left-justifying, and centering a string?

# %%
The rjust(), ljust(), and centering() string methods, respectively

# %% [markdown]
# ## 10. What is the best way to remove whitespace characters from the start or end?

# %%
The lstrip() and rstrip() methods the best way to  remove whitespace from the left and right start of a ends, respectively.
